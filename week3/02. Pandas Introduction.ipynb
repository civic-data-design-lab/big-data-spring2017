# %% [markdown]
# Big Data And Society: Lab 2
# =====

# %% [markdown]
# # Forking the Repository
#
# If you already have a copy of the repo, you can jump down to the next step.
#
# First, let's fork the course repo. A fork is a copy of a repository. Unlike cloning, when you fork a repo, it is attached to your account, and you are free to modify it, and edit, without affecting the original version... which is desirable for the context of the class.
#
# 1. First click fork on the github page
# 2. On GitHub, navigate to your fork of repository.
# 3. In the right sidebar of your fork's repository page, click  to copy the clone URL for your fork.
# 4. Open Terminal (for Mac and Linux users) or the command prompt (for Windows users).
# 5. Type git clone, and then paste the URL you copied in Step 2.
#
# ### Updating your Version to get Materials from the Main Class Repository
#
# To get the new materials from the main class repository, you need to commit any changes you've made locally and push them to your personal fork of the repo online. Then pull the repository from the main class repo.
#
# 1. Type git remote add upstream, and then paste the URL https://github.com/civic-data-design-lab/big-data-spring2017.git (you might get a message saying that this already exists, this is fine, it means this has already been done.)
# 2. To verify the new upstream repository you've specified for your fork, type **git remote -v**. You should see the URL for your fork as origin (remember your fork has **your username** in it), and the URL for the original repository as upstream (the one with the **civic-data-design-lab** in the URL).
# 3. Before you pull the upstream master repo, commit any changes you've made locally by following these steps:
#
# ===
#
# * Stage commits using **git add .**
# * Commit your staged changes using **git commit -m "my changes"**
# * Push your work to your forked repo. **git push origin master** (if you get a warning about LF conflicting with CRLF, this is not a problem, you can proceed)
#
# ===
#
# This will update your forked repo with any local changes.
#
# 4. Once this is done, **pull** the upstream repository (the main class repository). This will both fetch and merge the original repo into your local version. Do this using **git pull upstream master**
#
# Pulling from the remote repository will bring in its branches and their respective commits.

# %% [markdown]
# # Introduction to Pandas
# ![IPython](images/pandas.png "Pandas")
# **Pandas** is a library for Python for data manipulation and analysis. Pandas expands the data processing capacities of Python and adds a number of classes for easily importing data, in particular numerical tables, from various formats into their DataFrame object. A `DataFrame` is Panda’s basic object that allows multidimensional data processing and indexing. `DataFrames` can be easily and efficiently queried without the need of cumbersome syntax and convoluted loops. `DataFrames` can be merged with other data, they can be sliced, and they can be reshaped; in a way, we can think of Pandas as a big data combination of Excel and SQL.

# %% [markdown]
# ## Resources
#
# Pandas employs a number of functional and declarative programming idioms making it a bit different from regulay Python syntax. However, it is very close to functionality to **NumPy**, treating objects as vectors. In this exercise, **NumPy** is generally used for math functions.
#
# You can get a Cheatsheet to ease the learning curve, and learn about some of its functionality:
#
# https://drive.google.com/folderview?id=0ByIrJAE4KMTtaGhRcXkxNHhmY2M&usp=sharing

# %% [markdown]
# ### 0. Importing the library
# First we need to import the library, and use a shorter name for it:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Pandas and Data Frames
#
# You can think of a dataframe as a manipulable, multidimension Python array. They are based off of numpy arrays, can hold structured data, and you can perform functions on them to manage data, such as query, select, join, group. Let's setup a really simple dataframe.

# %%
# Create empty dataframe
df = pd.DataFrame()

# Create a column
df['name'] = ['Joey', 'Jeremy', 'Jenny']

# View dataframe
df
# Out:
#      name
# 0    Joey
# 1  Jeremy
# 2   Jenny

# %% [markdown]
# Say we want to add a column, its easy.

# %%
# Assign a new column to df called 'age' with a list of ages
df.assign(age = [28, 33, 27])
# Out:
#      name  age
# 0    Joey   28
# 1  Jeremy   33
# 2   Jenny   27

# %% [markdown]
# Data in this table can be manipulated, queried, sorted, and munged. Removing this for an inclass demo!
#
# ### 2. Reading Files
#
# This is cool, but you don't normally load data like this though, it gets tedious!
#
# Pandas provides a number of reader functions that process files and return a pandas object or `DataFrame`. Multiple different file types can be read, like **csv**, **txt**, **xls**, and **json**. The function parses the tabular data contained in the files and returns a formatted and indexed `DataFrame`. A number of additional arguments can be speficied, allowing to define the type of separator for text files, the header, the column to use as an index, etc.
#
# Additional documentation can be found on the API:
# http://pandas.pydata.org/pandas-docs/stable/index.html
#
# To start us off, lets look at a results file by precinct from the 2016 general election. This is an extract of results by precinct for Centre County, Pennsylvania.

# %%
# We are reading a CSV with election data
df = pd.read_table('data/centrecounty_precinct_results_nov2016.txt', sep=',')

# We can print the first 5 rows of the df
df.head()
# Out:
#                         County  ElecYear          Election         ElecDate  \
# 0  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 1  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 2  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 3  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 4  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
#
#    PrecNo             PrecName       Party                    Contest  Descr  \
# 0     1.0  01 BELLEFONTE NORTH         NaN  REGISTERED VOTERS - TOTAL    NaN
# 1     1.0  01 BELLEFONTE NORTH         NaN       BALLOTS CAST - TOTAL    NaN
# 2     1.0  01 BELLEFONTE NORTH         NaN      VOTER TURNOUT - TOTAL    NaN
# 3     1.0  01 BELLEFONTE NORTH  DEMOCRATIC             STRAIGHT PARTY    NaN
# 4     1.0  01 BELLEFONTE NORTH  REPUBLICAN             STRAIGHT PARTY    NaN
#
#                      VoteFor   Candidate  Posn  Count  PctCnt  Total  PctTot
# 0                        NaN         NaN  10.0  507.0     NaN    NaN     NaN
# 1                        NaN         NaN  11.0  391.0     NaN    NaN     NaN
# 2                        NaN         NaN  12.0    NaN   77.12    NaN     NaN
# 3  VOTE FOR NOT MORE THAN  1  DEMOCRATIC  17.0   46.0   40.35    NaN     NaN
# 4  VOTE FOR NOT MORE THAN  1  REPUBLICAN  18.0   66.0   57.89    NaN     NaN

# %% [markdown]
# Notice we have a table! A spreadsheet! And it indexed the rows. Pandas (borrowing from R) calls it a DataFrame. Lets see the types of the columns.
#
# `df`, in Python context, is an instance of the `pd.DataFrame` class, created by calling the `pd.read_table` function, which calls the DataFrame constructor inside of it. `df` is a dataframe object.

# %% [markdown]
# ### 2. DataFrame methods:
# The df object, for example, has methods, or functions belonging to it, which allow it to do things. For example `df.head()` is a method that shows the first 5 rows of the dataframe. `df.dtypes` returns the data types of each of the columns.
#
# Additional documentation can be found here: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html
# In general, the API is the best resource: http://pandas.pydata.org/pandas-docs/stable/api.html

# %%
df.dtypes
# Out:
# County        object
# ElecYear     float64
# Election      object
# ElecDate      object
# PrecNo       float64
# PrecName      object
# Party         object
# Contest       object
# Descr        float64
# VoteFor       object
# Candidate     object
# Posn         float64
# Count        float64
# PctCnt       float64
# Total        float64
# PctTot       float64
# dtype: object

# %% [markdown]
# The shape of the object is:

# %%
df.shape
# Out:
# (3526, 16)

# %% [markdown]
# 3526 rows times 16 columns. A spredsheet is a matrix. `df.shape` returns a tuple, so we can access members of this **tuple** like we do with a list:

# %%
df.shape[0], df.shape[1]
# Out:
# (3526, 16)

# %%
df.shape[0]
# Out:
# 3526

# %% [markdown]
# These are the column names:

# %%
df.columns
# Out:
# Index(['County', 'ElecYear', 'Election', 'ElecDate', 'PrecNo', 'PrecName',
#        'Party', 'Contest', 'Descr', 'VoteFor', 'Candidate', 'Posn', 'Count',
#        'PctCnt', 'Total', 'PctTot'],
#       dtype='object')

# %% [markdown]
# Notice that `df.columns` returns a `Pandas.Series` object. This object is built on top of the Python **lists**, and has similar methods and attributes.

# %% [markdown]
# Access an individual column.

# %%
df.Contest
# Out:
# 0                               REGISTERED VOTERS - TOTAL
# 1                                    BALLOTS CAST - TOTAL
# 2                                   VOTER TURNOUT - TOTAL
# 3                                          STRAIGHT PARTY
# 4                                          STRAIGHT PARTY
# 5                                          STRAIGHT PARTY
# 6                                          STRAIGHT PARTY
# 7                                          STRAIGHT PARTY
# 8                                   PRESIDENTIAL ELECTORS
# 9                                   PRESIDENTIAL ELECTORS
# 10                                  PRESIDENTIAL ELECTORS
# 11                                  PRESIDENTIAL ELECTORS
# 12                                  PRESIDENTIAL ELECTORS
# 13                                  PRESIDENTIAL ELECTORS
# 14                                  UNITED STATES SENATOR
# 15                                  UNITED STATES SENATOR
# 16                                  UNITED STATES SENATOR
# 17                                  UNITED STATES SENATOR
# 18                                       ATTORNEY GENERAL
# 19                                       ATTORNEY GENERAL
# 20                                       ATTORNEY GENERAL
# 21                                        AUDITOR GENERAL
# 22                                        AUDITOR GENERAL
# 23                                        AUDITOR GENERAL
# 24                                        AUDITOR GENERAL
# 25                                        AUDITOR GENERAL
# 26                                        STATE TREASURER
# 27                                        STATE TREASURER
# 28                                        STATE TREASURER
# 29                                        STATE TREASURER
#                               ...
# 3496                                UNITED STATES SENATOR
# 3497                                UNITED STATES SENATOR
# 3498                                UNITED STATES SENATOR
# 3499                                     ATTORNEY GENERAL
# 3500                                     ATTORNEY GENERAL
# 3501                                     ATTORNEY GENERAL
# 3502                                      AUDITOR GENERAL
# 3503                                      AUDITOR GENERAL
# 3504                                      AUDITOR GENERAL
# 3505                                      AUDITOR GENERAL
# 3506                                      AUDITOR GENERAL
# 3507                                      STATE TREASURER
# 3508                                      STATE TREASURER
# 3509                                      STATE TREASURER
# 3510                                      STATE TREASURER
# 3511                                      STATE TREASURER
# 3512         REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL
# 3513         REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL
# 3514         REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL
# 3515    REPRESENTATIVE IN THE GENERAL ASSEMBLY 171ST L...
# 3516    REPRESENTATIVE IN THE GENERAL ASSEMBLY 171ST L...
# 3517    REPRESENTATIVE IN THE GENERAL ASSEMBLY 171ST L...
# 3518                                           JUDGES AGE
# 3519                                           JUDGES AGE
# 3520                                                  NaN
# 3521                                                  NaN
# 3522                                                  NaN
# 3523                                                  NaN
# 3524                                                  NaN
# 3525                                                  NaN
# Name: Contest, dtype: object

# %% [markdown]
# We can use the unique() function to find the unique values in each column. Let's find the unique values in the Contest column

# %%
df.Contest.unique()
# Out:
# array(['REGISTERED VOTERS - TOTAL', 'BALLOTS CAST - TOTAL',
#        'VOTER TURNOUT - TOTAL', 'STRAIGHT PARTY', 'PRESIDENTIAL ELECTORS',
#        'UNITED STATES SENATOR', 'ATTORNEY GENERAL', 'AUDITOR GENERAL',
#        'STATE TREASURER', 'REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL',
#        'REPRESENTATIVE IN THE GENERAL ASSEMBLY 171ST LEGISLATIVE',
#        'JUDGES AGE',
#        'REPRESENTATIVE IN THE GENERAL ASSEMBLY 76TH LEGISLATIVE',
#        'REPRESENTATIVE IN THE GENERAL ASSEMBLY 77TH LEGISLATIVE',
#        'REPRESENTATIVE IN THE GENERAL ASSEMBLY 81ST LEGISLATIVE', nan], dtype=object)

# %% [markdown]
# Now lets get multiple columns:

# %%
df_multipleColumns = df[['Contest','PrecNo', 'Count']]
df_multipleColumns.head()
# Out:
#                      Contest  PrecNo  Count
# 0  REGISTERED VOTERS - TOTAL     1.0  507.0
# 1       BALLOTS CAST - TOTAL     1.0  391.0
# 2      VOTER TURNOUT - TOTAL     1.0    NaN
# 3             STRAIGHT PARTY     1.0   46.0
# 4             STRAIGHT PARTY     1.0   66.0

# %% [markdown]
# ### 3. Querying
#
# Pandas `DataFrames` have built-in methods for performing queries in a SQL style. They can be diced, sorted, etc it. We can apply any of this queries to parts of the `df`, and based on this query select subsets of the whole `df`. Let's do some filtering and querying.
#
# The output of this is a series.

# %%
df['PrecNo'] == 1
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 3496    False
# 3497    False
# 3498    False
# 3499    False
# 3500    False
# 3501    False
# 3502    False
# 3503    False
# 3504    False
# 3505    False
# 3506    False
# 3507    False
# 3508    False
# 3509    False
# 3510    False
# 3511    False
# 3512    False
# 3513    False
# 3514    False
# 3515    False
# 3516    False
# 3517    False
# 3518    False
# 3519    False
# 3520    False
# 3521    False
# 3522    False
# 3523    False
# 3524    False
# 3525    False
# Name: PrecNo, dtype: bool

# %% [markdown]
# To print out the table with only the rows we want, we can apply what is called a filter. The above is a series. Let's take a look again at **Precinct 1**. We can use the `df` mask to get a filtered dataframe: we use the mask to "index" into the dataframe to get the rows we want.

# %%
df_precinct1 = df[df['PrecNo'] == 1]

# %%
df_precinct1.head()
# Out:
#                         County  ElecYear          Election         ElecDate  \
# 0  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 1  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 2  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 3  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 4  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
#
#    PrecNo             PrecName       Party                    Contest  Descr  \
# 0     1.0  01 BELLEFONTE NORTH         NaN  REGISTERED VOTERS - TOTAL    NaN
# 1     1.0  01 BELLEFONTE NORTH         NaN       BALLOTS CAST - TOTAL    NaN
# 2     1.0  01 BELLEFONTE NORTH         NaN      VOTER TURNOUT - TOTAL    NaN
# 3     1.0  01 BELLEFONTE NORTH  DEMOCRATIC             STRAIGHT PARTY    NaN
# 4     1.0  01 BELLEFONTE NORTH  REPUBLICAN             STRAIGHT PARTY    NaN
#
#                      VoteFor   Candidate  Posn  Count  PctCnt  Total  PctTot
# 0                        NaN         NaN  10.0  507.0     NaN    NaN     NaN
# 1                        NaN         NaN  11.0  391.0     NaN    NaN     NaN
# 2                        NaN         NaN  12.0    NaN   77.12    NaN     NaN
# 3  VOTE FOR NOT MORE THAN  1  DEMOCRATIC  17.0   46.0   40.35    NaN     NaN
# 4  VOTE FOR NOT MORE THAN  1  REPUBLICAN  18.0   66.0   57.89    NaN     NaN

# %% [markdown]
# We can query based on multiple conditions, by using a `&` condition. All we need to do is add `()` brackets around each condition. The query uses a boolean AND. Each condition ceates a mask of trues and falses.

# %%
df[(df['PrecNo'] < 8) & (df['PrecNo'] > 5)]
# Out:
#                           County  ElecYear          Election         ElecDate  \
# 195  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 196  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 197  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 198  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 199  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 200  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 201  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 202  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 203  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 204  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 205  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 206  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 207  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 208  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 209  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 210  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 211  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 212  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 213  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 214  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 215  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 216  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 217  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 218  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 219  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 220  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 221  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 222  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 223  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 224  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# ..                           ...       ...               ...              ...
# 243  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 244  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 245  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 246  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 247  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 248  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 249  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 250  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 251  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 252  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 253  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 254  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 255  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 256  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 257  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 258  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 259  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 260  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 261  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 262  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 263  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 264  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 265  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 266  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 267  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 268  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 269  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 270  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 271  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 272  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
#
#      PrecNo        PrecName               Party  \
# 195     6.0  06 CENTRE HALL                 NaN
# 196     6.0  06 CENTRE HALL                 NaN
# 197     6.0  06 CENTRE HALL                 NaN
# 198     6.0  06 CENTRE HALL          DEMOCRATIC
# 199     6.0  06 CENTRE HALL          REPUBLICAN
# 200     6.0  06 CENTRE HALL  CONSTITUTION PARTY
# 201     6.0  06 CENTRE HALL               GREEN
# 202     6.0  06 CENTRE HALL         LIBERTARIAN
# 203     6.0  06 CENTRE HALL          DEMOCRATIC
# 204     6.0  06 CENTRE HALL          REPUBLICAN
# 205     6.0  06 CENTRE HALL  CONSTITUTION PARTY
# 206     6.0  06 CENTRE HALL               GREEN
# 207     6.0  06 CENTRE HALL         LIBERTARIAN
# 208     6.0  06 CENTRE HALL                 NaN
# 209     6.0  06 CENTRE HALL          DEMOCRATIC
# 210     6.0  06 CENTRE HALL          REPUBLICAN
# 211     6.0  06 CENTRE HALL         LIBERTARIAN
# 212     6.0  06 CENTRE HALL                 NaN
# 213     6.0  06 CENTRE HALL          DEMOCRATIC
# 214     6.0  06 CENTRE HALL          REPUBLICAN
# 215     6.0  06 CENTRE HALL                 NaN
# 216     6.0  06 CENTRE HALL          DEMOCRATIC
# 217     6.0  06 CENTRE HALL          REPUBLICAN
# 218     6.0  06 CENTRE HALL               GREEN
# 219     6.0  06 CENTRE HALL         LIBERTARIAN
# 220     6.0  06 CENTRE HALL                 NaN
# 221     6.0  06 CENTRE HALL          DEMOCRATIC
# 222     6.0  06 CENTRE HALL          REPUBLICAN
# 223     6.0  06 CENTRE HALL               GREEN
# 224     6.0  06 CENTRE HALL         LIBERTARIAN
# ..      ...             ...                 ...
# 243     7.0  07 HOWARD BORO          REPUBLICAN
# 244     7.0  07 HOWARD BORO  CONSTITUTION PARTY
# 245     7.0  07 HOWARD BORO               GREEN
# 246     7.0  07 HOWARD BORO         LIBERTARIAN
# 247     7.0  07 HOWARD BORO                 NaN
# 248     7.0  07 HOWARD BORO          DEMOCRATIC
# 249     7.0  07 HOWARD BORO          REPUBLICAN
# 250     7.0  07 HOWARD BORO         LIBERTARIAN
# 251     7.0  07 HOWARD BORO                 NaN
# 252     7.0  07 HOWARD BORO          DEMOCRATIC
# 253     7.0  07 HOWARD BORO          REPUBLICAN
# 254     7.0  07 HOWARD BORO                 NaN
# 255     7.0  07 HOWARD BORO          DEMOCRATIC
# 256     7.0  07 HOWARD BORO          REPUBLICAN
# 257     7.0  07 HOWARD BORO               GREEN
# 258     7.0  07 HOWARD BORO         LIBERTARIAN
# 259     7.0  07 HOWARD BORO                 NaN
# 260     7.0  07 HOWARD BORO          DEMOCRATIC
# 261     7.0  07 HOWARD BORO          REPUBLICAN
# 262     7.0  07 HOWARD BORO               GREEN
# 263     7.0  07 HOWARD BORO         LIBERTARIAN
# 264     7.0  07 HOWARD BORO                 NaN
# 265     7.0  07 HOWARD BORO          DEMOCRATIC
# 266     7.0  07 HOWARD BORO          REPUBLICAN
# 267     7.0  07 HOWARD BORO                 NaN
# 268     7.0  07 HOWARD BORO          DEMOCRATIC
# 269     7.0  07 HOWARD BORO          REPUBLICAN
# 270     7.0  07 HOWARD BORO                 NaN
# 271     7.0  07 HOWARD BORO                 NaN
# 272     7.0  07 HOWARD BORO                 NaN
#
#                                                Contest  Descr  \
# 195                          REGISTERED VOTERS - TOTAL    NaN
# 196                               BALLOTS CAST - TOTAL    NaN
# 197                              VOTER TURNOUT - TOTAL    NaN
# 198                                     STRAIGHT PARTY    NaN
# 199                                     STRAIGHT PARTY    NaN
# 200                                     STRAIGHT PARTY    NaN
# 201                                     STRAIGHT PARTY    NaN
# 202                                     STRAIGHT PARTY    NaN
# 203                              PRESIDENTIAL ELECTORS    NaN
# 204                              PRESIDENTIAL ELECTORS    NaN
# 205                              PRESIDENTIAL ELECTORS    NaN
# 206                              PRESIDENTIAL ELECTORS    NaN
# 207                              PRESIDENTIAL ELECTORS    NaN
# 208                              PRESIDENTIAL ELECTORS    NaN
# 209                              UNITED STATES SENATOR    NaN
# 210                              UNITED STATES SENATOR    NaN
# 211                              UNITED STATES SENATOR    NaN
# 212                              UNITED STATES SENATOR    NaN
# 213                                   ATTORNEY GENERAL    NaN
# 214                                   ATTORNEY GENERAL    NaN
# 215                                   ATTORNEY GENERAL    NaN
# 216                                    AUDITOR GENERAL    NaN
# 217                                    AUDITOR GENERAL    NaN
# 218                                    AUDITOR GENERAL    NaN
# 219                                    AUDITOR GENERAL    NaN
# 220                                    AUDITOR GENERAL    NaN
# 221                                    STATE TREASURER    NaN
# 222                                    STATE TREASURER    NaN
# 223                                    STATE TREASURER    NaN
# 224                                    STATE TREASURER    NaN
# ..                                                 ...    ...
# 243                              PRESIDENTIAL ELECTORS    NaN
# 244                              PRESIDENTIAL ELECTORS    NaN
# 245                              PRESIDENTIAL ELECTORS    NaN
# 246                              PRESIDENTIAL ELECTORS    NaN
# 247                              PRESIDENTIAL ELECTORS    NaN
# 248                              UNITED STATES SENATOR    NaN
# 249                              UNITED STATES SENATOR    NaN
# 250                              UNITED STATES SENATOR    NaN
# 251                              UNITED STATES SENATOR    NaN
# 252                                   ATTORNEY GENERAL    NaN
# 253                                   ATTORNEY GENERAL    NaN
# 254                                   ATTORNEY GENERAL    NaN
# 255                                    AUDITOR GENERAL    NaN
# 256                                    AUDITOR GENERAL    NaN
# 257                                    AUDITOR GENERAL    NaN
# 258                                    AUDITOR GENERAL    NaN
# 259                                    AUDITOR GENERAL    NaN
# 260                                    STATE TREASURER    NaN
# 261                                    STATE TREASURER    NaN
# 262                                    STATE TREASURER    NaN
# 263                                    STATE TREASURER    NaN
# 264                                    STATE TREASURER    NaN
# 265       REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL    NaN
# 266       REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL    NaN
# 267       REPRESENTATIVE IN CONGRESS 5TH CONGRESSIONAL    NaN
# 268  REPRESENTATIVE IN THE GENERAL ASSEMBLY 76TH LE...    NaN
# 269  REPRESENTATIVE IN THE GENERAL ASSEMBLY 76TH LE...    NaN
# 270  REPRESENTATIVE IN THE GENERAL ASSEMBLY 76TH LE...    NaN
# 271                                         JUDGES AGE    NaN
# 272                                         JUDGES AGE    NaN
#
#                        VoteFor                     Candidate   Posn  Count  \
# 195                        NaN                           NaN  435.0  892.0
# 196                        NaN                           NaN  436.0  709.0
# 197                        NaN                           NaN  437.0    NaN
# 198  VOTE FOR NOT MORE THAN  1                    DEMOCRATIC  442.0   62.0
# 199  VOTE FOR NOT MORE THAN  1                    REPUBLICAN  443.0  134.0
# 200  VOTE FOR NOT MORE THAN  1            CONSTITUTION PARTY  444.0    0.0
# 201  VOTE FOR NOT MORE THAN  1                         GREEN  445.0    2.0
# 202  VOTE FOR NOT MORE THAN  1                   LIBERTARIAN  446.0    2.0
# 203  VOTE FOR NOT MORE THAN  1   HILLARY CLINTON,  PRESIDENT  451.0  230.0
# 204  VOTE FOR NOT MORE THAN  1    DONALD J TRUMP,  PRESIDENT  452.0  443.0
# 205  VOTE FOR NOT MORE THAN  1  DARRELL L CASTLE,  PRESIDENT  453.0    2.0
# 206  VOTE FOR NOT MORE THAN  1        JILL STEIN,  PRESIDENT  454.0    2.0
# 207  VOTE FOR NOT MORE THAN  1       GARY JOHNSON, PRESIDENT  455.0   23.0
# 208  VOTE FOR NOT MORE THAN  1                      WRITE-IN  456.0    7.0
# 209  VOTE FOR NOT MORE THAN  1                 KATIE MCGINTY  461.0  239.0
# 210  VOTE FOR NOT MORE THAN  1                    PAT TOOMEY  462.0  400.0
# 211  VOTE FOR NOT MORE THAN  1        EDWARD T CLIFFORD, III  463.0   62.0
# 212  VOTE FOR NOT MORE THAN  1                      WRITE-IN  464.0    0.0
# 213  VOTE FOR NOT MORE THAN  1                  JOSH SHAPIRO  469.0  278.0
# 214  VOTE FOR NOT MORE THAN  1                 JOHN RAFFERTY  470.0  415.0
# 215  VOTE FOR NOT MORE THAN  1                      WRITE-IN  471.0    0.0
# 216  VOTE FOR NOT MORE THAN  1           EUGENE A DEPASQUALE  476.0  255.0
# 217  VOTE FOR NOT MORE THAN  1                    JOHN BROWN  477.0  385.0
# 218  VOTE FOR NOT MORE THAN  1                JOHN J SWEENEY  478.0   22.0
# 219  VOTE FOR NOT MORE THAN  1                   ROY A MINET  479.0   22.0
# 220  VOTE FOR NOT MORE THAN  1                      WRITE-IN  480.0    0.0
# 221  VOTE FOR NOT MORE THAN  1                  JOE TORSELLA  485.0  250.0
# 222  VOTE FOR NOT MORE THAN  1                     OTTO VOIT  486.0  365.0
# 223  VOTE FOR NOT MORE THAN  1                 KRISTIN COMBS  487.0   47.0
# 224  VOTE FOR NOT MORE THAN  1                    JAMES BABB  488.0   18.0
# ..                         ...                           ...    ...    ...
# 243  VOTE FOR NOT MORE THAN  1    DONALD J TRUMP,  PRESIDENT  537.0  228.0
# 244  VOTE FOR NOT MORE THAN  1  DARRELL L CASTLE,  PRESIDENT  538.0    4.0
# 245  VOTE FOR NOT MORE THAN  1        JILL STEIN,  PRESIDENT  539.0    1.0
# 246  VOTE FOR NOT MORE THAN  1       GARY JOHNSON, PRESIDENT  540.0   18.0
# 247  VOTE FOR NOT MORE THAN  1                      WRITE-IN  541.0    4.0
# 248  VOTE FOR NOT MORE THAN  1                 KATIE MCGINTY  546.0  124.0
# 249  VOTE FOR NOT MORE THAN  1                    PAT TOOMEY  547.0  218.0
# 250  VOTE FOR NOT MORE THAN  1        EDWARD T CLIFFORD, III  548.0   32.0
# 251  VOTE FOR NOT MORE THAN  1                      WRITE-IN  549.0    0.0
# 252  VOTE FOR NOT MORE THAN  1                  JOSH SHAPIRO  554.0  137.0
# 253  VOTE FOR NOT MORE THAN  1                 JOHN RAFFERTY  555.0  233.0
# 254  VOTE FOR NOT MORE THAN  1                      WRITE-IN  556.0    0.0
# 255  VOTE FOR NOT MORE THAN  1           EUGENE A DEPASQUALE  561.0  137.0
# 256  VOTE FOR NOT MORE THAN  1                    JOHN BROWN  562.0  197.0
# 257  VOTE FOR NOT MORE THAN  1                JOHN J SWEENEY  563.0   17.0
# 258  VOTE FOR NOT MORE THAN  1                   ROY A MINET  564.0   19.0
# 259  VOTE FOR NOT MORE THAN  1                      WRITE-IN  565.0    0.0
# 260  VOTE FOR NOT MORE THAN  1                  JOE TORSELLA  570.0  131.0
# 261  VOTE FOR NOT MORE THAN  1                     OTTO VOIT  571.0  194.0
# 262  VOTE FOR NOT MORE THAN  1                 KRISTIN COMBS  572.0   22.0
# 263  VOTE FOR NOT MORE THAN  1                    JAMES BABB  573.0   21.0
# 264  VOTE FOR NOT MORE THAN  1                      WRITE-IN  574.0    0.0
# 265  VOTE FOR NOT MORE THAN  1          KERITH STRANO TAYLOR  578.0   94.0
# 266  VOTE FOR NOT MORE THAN  1             GLENN GT THOMPSON  579.0  275.0
# 267  VOTE FOR NOT MORE THAN  1                      WRITE-IN  580.0    0.0
# 268  VOTE FOR NOT MORE THAN  1                    MIKE HANNA  585.0  178.0
# 269  VOTE FOR NOT MORE THAN  1            STEPHANIE BOROWICZ  586.0  191.0
# 270  VOTE FOR NOT MORE THAN  1                      WRITE-IN  587.0    1.0
# 271  VOTE FOR NOT MORE THAN  1                           YES  592.0  159.0
# 272  VOTE FOR NOT MORE THAN  1                            NO  593.0  146.0
#
#      PctCnt  Total  PctTot
# 195     NaN    NaN     NaN
# 196     NaN    NaN     NaN
# 197   79.48    NaN     NaN
# 198   31.00    NaN     NaN
# 199   67.00    NaN     NaN
# 200     NaN    NaN     NaN
# 201    1.00    NaN     NaN
# 202    1.00    NaN     NaN
# 203   32.53    NaN     NaN
# 204   62.66    NaN     NaN
# 205    0.28    NaN     NaN
# 206    0.28    NaN     NaN
# 207    3.25    NaN     NaN
# 208    0.99    NaN     NaN
# 209   34.09    NaN     NaN
# 210   57.06    NaN     NaN
# 211    8.84    NaN     NaN
# 212     NaN    NaN     NaN
# 213   40.12    NaN     NaN
# 214   59.88    NaN     NaN
# 215     NaN    NaN     NaN
# 216   37.28    NaN     NaN
# 217   56.29    NaN     NaN
# 218    3.22    NaN     NaN
# 219    3.22    NaN     NaN
# 220     NaN    NaN     NaN
# 221   36.76    NaN     NaN
# 222   53.68    NaN     NaN
# 223    6.91    NaN     NaN
# 224    2.65    NaN     NaN
# ..      ...    ...     ...
# 243   60.48    NaN     NaN
# 244    1.06    NaN     NaN
# 245    0.27    NaN     NaN
# 246    4.77    NaN     NaN
# 247    1.06    NaN     NaN
# 248   33.16    NaN     NaN
# 249   58.29    NaN     NaN
# 250    8.56    NaN     NaN
# 251     NaN    NaN     NaN
# 252   37.03    NaN     NaN
# 253   62.97    NaN     NaN
# 254     NaN    NaN     NaN
# 255   37.03    NaN     NaN
# 256   53.24    NaN     NaN
# 257    4.59    NaN     NaN
# 258    5.14    NaN     NaN
# 259     NaN    NaN     NaN
# 260   35.60    NaN     NaN
# 261   52.72    NaN     NaN
# 262    5.98    NaN     NaN
# 263    5.71    NaN     NaN
# 264     NaN    NaN     NaN
# 265   25.47    NaN     NaN
# 266   74.53    NaN     NaN
# 267     NaN    NaN     NaN
# 268   48.11    NaN     NaN
# 269   51.62    NaN     NaN
# 270    0.27    NaN     NaN
# 271   52.13    NaN     NaN
# 272   47.87    NaN     NaN
#
# [78 rows x 16 columns]

# %% [markdown]
# Because this dataset contains all of the different contests in the November generals, we can use a query to pull out just the presidential election. Here we use [df.loc](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.loc.html) to select by label and find only those listings for the presidential election.

# %%
df_pres = df.loc[df['Contest'] == 'PRESIDENTIAL ELECTORS']
df_pres
# Out:
#                            County  ElecYear          Election  \
# 8     CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 9     CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 10    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 11    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 12    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 13    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 47    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 48    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 49    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 50    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 51    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 52    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 86    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 87    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 88    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 89    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 90    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 91    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 125   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 126   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 127   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 128   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 129   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 130   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 164   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 165   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 166   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 167   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 168   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 169   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# ...                           ...       ...               ...
# 3333  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3334  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3335  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3336  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3337  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3338  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3372  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3373  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3374  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3375  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3376  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3377  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3411  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3412  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3413  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3414  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3415  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3416  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3450  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3451  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3452  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3453  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3454  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3455  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3489  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3490  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3491  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3492  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3493  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
# 3494  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
#
#              ElecDate  PrecNo                   PrecName               Party  \
# 8     NOVEMBER 8 2016     1.0        01 BELLEFONTE NORTH          DEMOCRATIC
# 9     NOVEMBER 8 2016     1.0        01 BELLEFONTE NORTH          REPUBLICAN
# 10    NOVEMBER 8 2016     1.0        01 BELLEFONTE NORTH  CONSTITUTION PARTY
# 11    NOVEMBER 8 2016     1.0        01 BELLEFONTE NORTH               GREEN
# 12    NOVEMBER 8 2016     1.0        01 BELLEFONTE NORTH         LIBERTARIAN
# 13    NOVEMBER 8 2016     1.0        01 BELLEFONTE NORTH                 NaN
# 47    NOVEMBER 8 2016     2.0    02 BELLEFONTE NORTHEAST          DEMOCRATIC
# 48    NOVEMBER 8 2016     2.0    02 BELLEFONTE NORTHEAST          REPUBLICAN
# 49    NOVEMBER 8 2016     2.0    02 BELLEFONTE NORTHEAST  CONSTITUTION PARTY
# 50    NOVEMBER 8 2016     2.0    02 BELLEFONTE NORTHEAST               GREEN
# 51    NOVEMBER 8 2016     2.0    02 BELLEFONTE NORTHEAST         LIBERTARIAN
# 52    NOVEMBER 8 2016     2.0    02 BELLEFONTE NORTHEAST                 NaN
# 86    NOVEMBER 8 2016     3.0        03 BELLEFONTE SOUTH          DEMOCRATIC
# 87    NOVEMBER 8 2016     3.0        03 BELLEFONTE SOUTH          REPUBLICAN
# 88    NOVEMBER 8 2016     3.0        03 BELLEFONTE SOUTH  CONSTITUTION PARTY
# 89    NOVEMBER 8 2016     3.0        03 BELLEFONTE SOUTH               GREEN
# 90    NOVEMBER 8 2016     3.0        03 BELLEFONTE SOUTH         LIBERTARIAN
# 91    NOVEMBER 8 2016     3.0        03 BELLEFONTE SOUTH                 NaN
# 125   NOVEMBER 8 2016     4.0    04 BELLEFONTE SOUTHEAST          DEMOCRATIC
# 126   NOVEMBER 8 2016     4.0    04 BELLEFONTE SOUTHEAST          REPUBLICAN
# 127   NOVEMBER 8 2016     4.0    04 BELLEFONTE SOUTHEAST  CONSTITUTION PARTY
# 128   NOVEMBER 8 2016     4.0    04 BELLEFONTE SOUTHEAST               GREEN
# 129   NOVEMBER 8 2016     4.0    04 BELLEFONTE SOUTHEAST         LIBERTARIAN
# 130   NOVEMBER 8 2016     4.0    04 BELLEFONTE SOUTHEAST                 NaN
# 164   NOVEMBER 8 2016     5.0         05 BELLEFONTE WEST          DEMOCRATIC
# 165   NOVEMBER 8 2016     5.0         05 BELLEFONTE WEST          REPUBLICAN
# 166   NOVEMBER 8 2016     5.0         05 BELLEFONTE WEST  CONSTITUTION PARTY
# 167   NOVEMBER 8 2016     5.0         05 BELLEFONTE WEST               GREEN
# 168   NOVEMBER 8 2016     5.0         05 BELLEFONTE WEST         LIBERTARIAN
# 169   NOVEMBER 8 2016     5.0         05 BELLEFONTE WEST                 NaN
# ...               ...     ...                        ...                 ...
# 3333  NOVEMBER 8 2016    87.0        87 SPRING SOUTHWEST          DEMOCRATIC
# 3334  NOVEMBER 8 2016    87.0        87 SPRING SOUTHWEST          REPUBLICAN
# 3335  NOVEMBER 8 2016    87.0        87 SPRING SOUTHWEST  CONSTITUTION PARTY
# 3336  NOVEMBER 8 2016    87.0        87 SPRING SOUTHWEST               GREEN
# 3337  NOVEMBER 8 2016    87.0        87 SPRING SOUTHWEST         LIBERTARIAN
# 3338  NOVEMBER 8 2016    87.0        87 SPRING SOUTHWEST                 NaN
# 3372  NOVEMBER 8 2016    88.0        88 FERGUSON NORTH 3          DEMOCRATIC
# 3373  NOVEMBER 8 2016    88.0        88 FERGUSON NORTH 3          REPUBLICAN
# 3374  NOVEMBER 8 2016    88.0        88 FERGUSON NORTH 3  CONSTITUTION PARTY
# 3375  NOVEMBER 8 2016    88.0        88 FERGUSON NORTH 3               GREEN
# 3376  NOVEMBER 8 2016    88.0        88 FERGUSON NORTH 3         LIBERTARIAN
# 3377  NOVEMBER 8 2016    88.0        88 FERGUSON NORTH 3                 NaN
# 3411  NOVEMBER 8 2016    89.0   89 FERGUSON WEST CENTRAL          DEMOCRATIC
# 3412  NOVEMBER 8 2016    89.0   89 FERGUSON WEST CENTRAL          REPUBLICAN
# 3413  NOVEMBER 8 2016    89.0   89 FERGUSON WEST CENTRAL  CONSTITUTION PARTY
# 3414  NOVEMBER 8 2016    89.0   89 FERGUSON WEST CENTRAL               GREEN
# 3415  NOVEMBER 8 2016    89.0   89 FERGUSON WEST CENTRAL         LIBERTARIAN
# 3416  NOVEMBER 8 2016    89.0   89 FERGUSON WEST CENTRAL                 NaN
# 3450  NOVEMBER 8 2016    90.0   90 HALFMOON EAST CENTRAL          DEMOCRATIC
# 3451  NOVEMBER 8 2016    90.0   90 HALFMOON EAST CENTRAL          REPUBLICAN
# 3452  NOVEMBER 8 2016    90.0   90 HALFMOON EAST CENTRAL  CONSTITUTION PARTY
# 3453  NOVEMBER 8 2016    90.0   90 HALFMOON EAST CENTRAL               GREEN
# 3454  NOVEMBER 8 2016    90.0   90 HALFMOON EAST CENTRAL         LIBERTARIAN
# 3455  NOVEMBER 8 2016    90.0   90 HALFMOON EAST CENTRAL                 NaN
# 3489  NOVEMBER 8 2016    91.0  91 FERGUSON NORTH CENTRAL          DEMOCRATIC
# 3490  NOVEMBER 8 2016    91.0  91 FERGUSON NORTH CENTRAL          REPUBLICAN
# 3491  NOVEMBER 8 2016    91.0  91 FERGUSON NORTH CENTRAL  CONSTITUTION PARTY
# 3492  NOVEMBER 8 2016    91.0  91 FERGUSON NORTH CENTRAL               GREEN
# 3493  NOVEMBER 8 2016    91.0  91 FERGUSON NORTH CENTRAL         LIBERTARIAN
# 3494  NOVEMBER 8 2016    91.0  91 FERGUSON NORTH CENTRAL                 NaN
#
#                     Contest  Descr                    VoteFor  \
# 8     PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 9     PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 10    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 11    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 12    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 13    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 47    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 48    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 49    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 50    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 51    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 52    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 86    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 87    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 88    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 89    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 90    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 91    PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 125   PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 126   PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 127   PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 128   PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 129   PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 130   PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 164   PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 165   PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 166   PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 167   PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 168   PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 169   PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# ...                     ...    ...                        ...
# 3333  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3334  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3335  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3336  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3337  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3338  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3372  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3373  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3374  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3375  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3376  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3377  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3411  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3412  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3413  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3414  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3415  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3416  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3450  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3451  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3452  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3453  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3454  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3455  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3489  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3490  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3491  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3492  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3493  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
# 3494  PRESIDENTIAL ELECTORS    NaN  VOTE FOR NOT MORE THAN  1
#
#                          Candidate    Posn  Count  PctCnt  Total  PctTot
# 8      HILLARY CLINTON,  PRESIDENT    26.0  188.0   48.08    NaN     NaN
# 9       DONALD J TRUMP,  PRESIDENT    27.0  174.0   44.50    NaN     NaN
# 10    DARRELL L CASTLE,  PRESIDENT    28.0    2.0    0.51    NaN     NaN
# 11          JILL STEIN,  PRESIDENT    29.0    3.0    0.77    NaN     NaN
# 12         GARY JOHNSON, PRESIDENT    30.0   22.0    5.63    NaN     NaN
# 13                        WRITE-IN    31.0    2.0    0.51    NaN     NaN
# 47     HILLARY CLINTON,  PRESIDENT   111.0  259.0   38.14    NaN     NaN
# 48      DONALD J TRUMP,  PRESIDENT   112.0  385.0   56.70    NaN     NaN
# 49    DARRELL L CASTLE,  PRESIDENT   113.0    9.0    1.33    NaN     NaN
# 50          JILL STEIN,  PRESIDENT   114.0    7.0    1.03    NaN     NaN
# 51         GARY JOHNSON, PRESIDENT   115.0   10.0    1.47    NaN     NaN
# 52                        WRITE-IN   116.0    9.0    1.33    NaN     NaN
# 86     HILLARY CLINTON,  PRESIDENT   196.0  230.0   50.33    NaN     NaN
# 87      DONALD J TRUMP,  PRESIDENT   197.0  193.0   42.23    NaN     NaN
# 88    DARRELL L CASTLE,  PRESIDENT   198.0    6.0    1.31    NaN     NaN
# 89          JILL STEIN,  PRESIDENT   199.0    4.0    0.88    NaN     NaN
# 90         GARY JOHNSON, PRESIDENT   200.0   17.0    3.72    NaN     NaN
# 91                        WRITE-IN   201.0    7.0    1.53    NaN     NaN
# 125    HILLARY CLINTON,  PRESIDENT   281.0  283.0   39.47    NaN     NaN
# 126     DONALD J TRUMP,  PRESIDENT   282.0  375.0   52.30    NaN     NaN
# 127   DARRELL L CASTLE,  PRESIDENT   283.0    6.0    0.84    NaN     NaN
# 128         JILL STEIN,  PRESIDENT   284.0   10.0    1.39    NaN     NaN
# 129        GARY JOHNSON, PRESIDENT   285.0   35.0    4.88    NaN     NaN
# 130                       WRITE-IN   286.0    8.0    1.12    NaN     NaN
# 164    HILLARY CLINTON,  PRESIDENT   366.0  443.0   48.05    NaN     NaN
# 165     DONALD J TRUMP,  PRESIDENT   367.0  398.0   43.17    NaN     NaN
# 166   DARRELL L CASTLE,  PRESIDENT   368.0    7.0    0.76    NaN     NaN
# 167         JILL STEIN,  PRESIDENT   369.0   13.0    1.41    NaN     NaN
# 168        GARY JOHNSON, PRESIDENT   370.0   48.0    5.21    NaN     NaN
# 169                       WRITE-IN   371.0   13.0    1.41    NaN     NaN
# ...                            ...     ...    ...     ...    ...     ...
# 3333   HILLARY CLINTON,  PRESIDENT  7311.0  343.0   37.40    NaN     NaN
# 3334    DONALD J TRUMP,  PRESIDENT  7312.0  509.0   55.51    NaN     NaN
# 3335  DARRELL L CASTLE,  PRESIDENT  7313.0    6.0    0.65    NaN     NaN
# 3336        JILL STEIN,  PRESIDENT  7314.0    5.0    0.55    NaN     NaN
# 3337       GARY JOHNSON, PRESIDENT  7315.0   44.0    4.80    NaN     NaN
# 3338                      WRITE-IN  7316.0   10.0    1.09    NaN     NaN
# 3372   HILLARY CLINTON,  PRESIDENT  7396.0  642.0   64.46    NaN     NaN
# 3373    DONALD J TRUMP,  PRESIDENT  7397.0  292.0   29.32    NaN     NaN
# 3374  DARRELL L CASTLE,  PRESIDENT  7398.0    9.0    0.90    NaN     NaN
# 3375        JILL STEIN,  PRESIDENT  7399.0   10.0    1.00    NaN     NaN
# 3376       GARY JOHNSON, PRESIDENT  7400.0   19.0    1.91    NaN     NaN
# 3377                      WRITE-IN  7401.0   24.0    2.41    NaN     NaN
# 3411   HILLARY CLINTON,  PRESIDENT  7481.0  628.0   57.67    NaN     NaN
# 3412    DONALD J TRUMP,  PRESIDENT  7482.0  391.0   35.90    NaN     NaN
# 3413  DARRELL L CASTLE,  PRESIDENT  7483.0    3.0    0.28    NaN     NaN
# 3414        JILL STEIN,  PRESIDENT  7484.0    6.0    0.55    NaN     NaN
# 3415       GARY JOHNSON, PRESIDENT  7485.0   39.0    3.58    NaN     NaN
# 3416                      WRITE-IN  7486.0   22.0    2.02    NaN     NaN
# 3450   HILLARY CLINTON,  PRESIDENT  7566.0  394.0   39.44    NaN     NaN
# 3451    DONALD J TRUMP,  PRESIDENT  7567.0  536.0   53.65    NaN     NaN
# 3452  DARRELL L CASTLE,  PRESIDENT  7568.0    0.0     NaN    NaN     NaN
# 3453        JILL STEIN,  PRESIDENT  7569.0   13.0    1.30    NaN     NaN
# 3454       GARY JOHNSON, PRESIDENT  7570.0   37.0    3.70    NaN     NaN
# 3455                      WRITE-IN  7571.0   19.0    1.90    NaN     NaN
# 3489   HILLARY CLINTON,  PRESIDENT  7651.0  396.0   55.54    NaN     NaN
# 3490    DONALD J TRUMP,  PRESIDENT  7652.0  281.0   39.41    NaN     NaN
# 3491  DARRELL L CASTLE,  PRESIDENT  7653.0    1.0    0.14    NaN     NaN
# 3492        JILL STEIN,  PRESIDENT  7654.0    6.0    0.84    NaN     NaN
# 3493       GARY JOHNSON, PRESIDENT  7655.0   16.0    2.24    NaN     NaN
# 3494                      WRITE-IN  7656.0   13.0    1.82    NaN     NaN
#
# [546 rows x 16 columns]

# %% [markdown]
# Now that we are looking just at the votes for the presidential election, we can find, for example, which rows show votes for Hillary Clinton.

# %%
df_clinton = df_pres.loc[df_pres['Candidate'] == 'HILLARY CLINTON,  PRESIDENT']
df_clinton.head()
# Out:
#                           County  ElecYear          Election         ElecDate  \
# 8    CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 47   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 86   CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 125  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
# 164  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
#
#      PrecNo                 PrecName       Party                Contest  \
# 8       1.0      01 BELLEFONTE NORTH  DEMOCRATIC  PRESIDENTIAL ELECTORS
# 47      2.0  02 BELLEFONTE NORTHEAST  DEMOCRATIC  PRESIDENTIAL ELECTORS
# 86      3.0      03 BELLEFONTE SOUTH  DEMOCRATIC  PRESIDENTIAL ELECTORS
# 125     4.0  04 BELLEFONTE SOUTHEAST  DEMOCRATIC  PRESIDENTIAL ELECTORS
# 164     5.0       05 BELLEFONTE WEST  DEMOCRATIC  PRESIDENTIAL ELECTORS
#
#      Descr                    VoteFor                    Candidate   Posn  \
# 8      NaN  VOTE FOR NOT MORE THAN  1  HILLARY CLINTON,  PRESIDENT   26.0
# 47     NaN  VOTE FOR NOT MORE THAN  1  HILLARY CLINTON,  PRESIDENT  111.0
# 86     NaN  VOTE FOR NOT MORE THAN  1  HILLARY CLINTON,  PRESIDENT  196.0
# 125    NaN  VOTE FOR NOT MORE THAN  1  HILLARY CLINTON,  PRESIDENT  281.0
# 164    NaN  VOTE FOR NOT MORE THAN  1  HILLARY CLINTON,  PRESIDENT  366.0
#
#      Count  PctCnt  Total  PctTot
# 8    188.0   48.08    NaN     NaN
# 47   259.0   38.14    NaN     NaN
# 86   230.0   50.33    NaN     NaN
# 125  283.0   39.47    NaN     NaN
# 164  443.0   48.05    NaN     NaN

# %%
df_pres['Candidate'].unique()
# Out:
# array(['HILLARY CLINTON,  PRESIDENT', 'DONALD J TRUMP,  PRESIDENT',
#        'DARRELL L CASTLE,  PRESIDENT', 'JILL STEIN,  PRESIDENT',
#        'GARY JOHNSON, PRESIDENT', 'WRITE-IN'], dtype=object)

# %% [markdown]
# Since these rows are the ones that have voted for Clinton, we can perform operations to locate which rows (ie which precincts) had more than 50% of the vote go to Clinton.
#
# This gives us a `Pandas.Series` of `True`s and `False`s. We call this a mask.

# %%
df_clinton.PctCnt > 50
# Out:
# 8       False
# 47      False
# 86       True
# 125     False
# 164     False
# 203     False
# 242     False
# 281     False
# 320     False
# 359     False
# 397     False
# 435     False
# 473     False
# 512     False
# 551     False
# 589      True
# 627      True
# 665      True
# 703      True
# 741      True
# 779      True
# 817      True
# 855      True
# 893      True
# 931      True
# 969      True
# 1007     True
# 1045     True
# 1083     True
# 1121     True
#         ...
# 2364    False
# 2403    False
# 2442     True
# 2480    False
# 2519     True
# 2558     True
# 2596     True
# 2635    False
# 2674    False
# 2713    False
# 2752    False
# 2790    False
# 2828    False
# 2866    False
# 2904    False
# 2943    False
# 2982    False
# 3021    False
# 3060    False
# 3099    False
# 3138    False
# 3177    False
# 3216    False
# 3255    False
# 3294    False
# 3333    False
# 3372     True
# 3411     True
# 3450    False
# 3489     True
# Name: PctCnt, dtype: bool

# %% [markdown]
# We can summarize the Count field for the rows that represent Clinton.

# %%
df_clinton.Count.sum()
# Out:
# 37088.0

# %% [markdown]
# Say we want to summary for all of the candidates, lets go back to the **df_pres** table we made and group by the candidate, then sum the count.

# %%
df_pres.groupby('Candidate').Count.sum()
# Out:
# Candidate
# DARRELL L CASTLE,  PRESIDENT      344.0
# DONALD J TRUMP,  PRESIDENT      35274.0
# GARY JOHNSON, PRESIDENT          2644.0
# HILLARY CLINTON,  PRESIDENT     37088.0
# JILL STEIN,  PRESIDENT            798.0
# WRITE-IN                         1159.0
# Name: Count, dtype: float64

# %% [markdown]
# We can group by with multiple columns. This will allow us to look at the results from each precinct.

# %%
df_pres.groupby(['PrecNo','Candidate']).Count.sum()
# Out:
# PrecNo  Candidate
# 1.0     DARRELL L CASTLE,  PRESIDENT      2.0
#         DONALD J TRUMP,  PRESIDENT      174.0
#         GARY JOHNSON, PRESIDENT          22.0
#         HILLARY CLINTON,  PRESIDENT     188.0
#         JILL STEIN,  PRESIDENT            3.0
#         WRITE-IN                          2.0
# 2.0     DARRELL L CASTLE,  PRESIDENT      9.0
#         DONALD J TRUMP,  PRESIDENT      385.0
#         GARY JOHNSON, PRESIDENT          10.0
#         HILLARY CLINTON,  PRESIDENT     259.0
#         JILL STEIN,  PRESIDENT            7.0
#         WRITE-IN                          9.0
# 3.0     DARRELL L CASTLE,  PRESIDENT      6.0
#         DONALD J TRUMP,  PRESIDENT      193.0
#         GARY JOHNSON, PRESIDENT          17.0
#         HILLARY CLINTON,  PRESIDENT     230.0
#         JILL STEIN,  PRESIDENT            4.0
#         WRITE-IN                          7.0
# 4.0     DARRELL L CASTLE,  PRESIDENT      6.0
#         DONALD J TRUMP,  PRESIDENT      375.0
#         GARY JOHNSON, PRESIDENT          35.0
#         HILLARY CLINTON,  PRESIDENT     283.0
#         JILL STEIN,  PRESIDENT           10.0
#         WRITE-IN                          8.0
# 5.0     DARRELL L CASTLE,  PRESIDENT      7.0
#         DONALD J TRUMP,  PRESIDENT      398.0
#         GARY JOHNSON, PRESIDENT          48.0
#         HILLARY CLINTON,  PRESIDENT     443.0
#         JILL STEIN,  PRESIDENT           13.0
#         WRITE-IN                         13.0
#                                         ...
# 87.0    DARRELL L CASTLE,  PRESIDENT      6.0
#         DONALD J TRUMP,  PRESIDENT      509.0
#         GARY JOHNSON, PRESIDENT          44.0
#         HILLARY CLINTON,  PRESIDENT     343.0
#         JILL STEIN,  PRESIDENT            5.0
#         WRITE-IN                         10.0
# 88.0    DARRELL L CASTLE,  PRESIDENT      9.0
#         DONALD J TRUMP,  PRESIDENT      292.0
#         GARY JOHNSON, PRESIDENT          19.0
#         HILLARY CLINTON,  PRESIDENT     642.0
#         JILL STEIN,  PRESIDENT           10.0
#         WRITE-IN                         24.0
# 89.0    DARRELL L CASTLE,  PRESIDENT      3.0
#         DONALD J TRUMP,  PRESIDENT      391.0
#         GARY JOHNSON, PRESIDENT          39.0
#         HILLARY CLINTON,  PRESIDENT     628.0
#         JILL STEIN,  PRESIDENT            6.0
#         WRITE-IN                         22.0
# 90.0    DARRELL L CASTLE,  PRESIDENT      0.0
#         DONALD J TRUMP,  PRESIDENT      536.0
#         GARY JOHNSON, PRESIDENT          37.0
#         HILLARY CLINTON,  PRESIDENT     394.0
#         JILL STEIN,  PRESIDENT           13.0
#         WRITE-IN                         19.0
# 91.0    DARRELL L CASTLE,  PRESIDENT      1.0
#         DONALD J TRUMP,  PRESIDENT      281.0
#         GARY JOHNSON, PRESIDENT          16.0
#         HILLARY CLINTON,  PRESIDENT     396.0
#         JILL STEIN,  PRESIDENT            6.0
#         WRITE-IN                         13.0
# Name: Count, dtype: float64

# %% [markdown]
# Or directly, in Pandas, which works since `df_pres` is a pandas Series. Pandas series have a number of built-in methods like `.max()`, `.min()`, and `.mean()`!

# %%
df_clinton['Count'].max()
# Out:
# 1195.0

# %% [markdown]
# You can save these as variables. And cast them to strings.

# %%
# create min, max, and mean
max_clinton = df_clinton['Count'].max()
min_clinton = df_clinton['Count'].min()
mean_clinton = df_clinton['Count'].mean()

# print out some results
print("Highest precinct vote total for Clinton: " + str(max_clinton))
print("Lowest precinct vote total for Clinton: " + str(min_clinton))
print("Mean precinct vote total for Clinton: " + str(mean_clinton))
# Out:
# Highest precinct vote total for Clinton: 1195.0
# Lowest precinct vote total for Clinton: 18.0
# Mean precinct vote total for Clinton: 407.56043956

# %% [markdown]
# This isn't super useful though, so we can get the whole row of the max and min values of the percentage vote, use the following query.

# %%
df_clinton.loc[df['PctCnt'] == df_clinton['PctCnt'].max()]
# Out:
#                           County  ElecYear          Election         ElecDate  \
# 589  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION  NOVEMBER 8 2016
#
#      PrecNo     PrecName       Party                Contest  Descr  \
# 589    16.0  16 SC NORTH  DEMOCRATIC  PRESIDENTIAL ELECTORS    NaN
#
#                        VoteFor                    Candidate    Posn  Count  \
# 589  VOTE FOR NOT MORE THAN  1  HILLARY CLINTON,  PRESIDENT  1297.0  495.0
#
#      PctCnt  Total  PctTot
# 589   77.95    NaN     NaN

# %% [markdown]
# Here, Clinton took 77% of the vote!

# %%
df_clinton.loc[df['PctCnt'] == df_clinton['PctCnt'].min()]
# Out:
#                            County  ElecYear          Election  \
# 3138  CENTRE COUNTY, PENNSYLVANIA    2016.0  GENERAL ELECTION
#
#              ElecDate  PrecNo  PrecName       Party                Contest  \
# 3138  NOVEMBER 8 2016    82.0  82 UNION  DEMOCRATIC  PRESIDENTIAL ELECTORS
#
#       Descr                    VoteFor                    Candidate    Posn  \
# 3138    NaN  VOTE FOR NOT MORE THAN  1  HILLARY CLINTON,  PRESIDENT  6886.0
#
#       Count  PctCnt  Total  PctTot
# 3138  126.0   17.03    NaN     NaN

# %% [markdown]
# In this precinct, Clinton took only 17% of the votes.
#
# #### Exercise:
#
# Calculate the minimum value, and maximum value of the `Count` column to find the precincts with the highest and lowest turnouts by percentage. Hint, you'll want to filter by `Contest`. [This](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.min.html#pandas.Series.min) documentation might be useful.

# %%
# Your code here

# %% [markdown]
# #### Exercise:
# Get the average actual number of people that turned out to vote by precinct across the whole dataset. [Documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.subtract.html#pandas.Series.subtract)

# %%
# Your code here

# %% [markdown]
# ### 5. Cleaning
#
# One of the most common tasks while working with big data is data cleaning. Datasets will be inherently heterogeneous and unstructured. The lack of structure can cause functions to throw errors. We can clean data sets through various methods; if the discrepancies follow a structured pattern, it is possible to use built-in functions, or write our own functions. However, if the errors cannot be structured, we might have to do it manually!
#
# For this example, we first check the datatypes:

# %%
df.dtypes

# %%
df.shape

# %% [markdown]
# A common cause of errors is having Null or 'None' values. This usually means data was missing.

# %%
df[df['PrecNo'].isnull()]

# %% [markdown]
# We had some incomplete data! We can get rid of it with the `.notnull()` function.

# %%
df = df[df['PrecNo'].notnull()]
df.shape

# %% [markdown]
# We removed those 6 rows. Important note, this is working in memory! We are not actually changing the table, do to so, you can export your output to a CSV.

# %% [markdown]
# ### 6. Split-apply-combine (Joins!)
#
# With Pandas we can split the data into groups based on some criteria. We can then apply a function to each group independently, and finally combine the results into a new data structure.

# %% [markdown]
# <img src=http://i.imgur.com/yjNkiwL.png></img>

# %% [markdown]
# #### Group Registered Voter Data and Compare Numbers
#
# Let’s look at a network file of Riyadh. The network was generated based on cell phone data, and it represents cell phone towers in the area, and the flow among them. In this example, we are going to:
#
# * Split data per node ID. We will be grouping the dataset by their source node ID.
# * sum their voc (volume/capacity). Once we had grouped them, we can sum by source node.
# * combine the result. We can finally perform operations on the grouped dataset.

# %%
# Import the file
# Note: It's a big one! You can work with large files in Pandas with ease.
# However, you might need to set the low memory option to False.
df_voters = pd.read_table('data/CENTRE_FVE_20170123.csv', sep=',', low_memory=False)
df_voters

# %%
# Get the row count
df_voters.shape

# %%
# change column datatype to int for Field 27
df_voters['27'].unique()

# %% [markdown]
# Our table is 123443 rows long, by 153 columns. For a data dictionary, see the data folder. Looking at our metadata, our precinct code is held in Field 27.

# %%
# Group the edges by their source
grouped = df_voters.groupby('27')
summed = grouped['27'].count()

# get a series
summed.head()

# %%
# Convert our series to a dataframe so we can work with it further
df_summed_extract = summed.to_frame()
# df_summed_extract.index = df_summed_extract.index.map(int)
df_summed_extract.head()

# %% [markdown]
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Index.rename.html

# %%
# lets rename things so they make more sense
df_summed_extract.columns = ['Count']
df_summed_extract.index.names = ['Precinct']
df_summed_extract

# %% [markdown]
# Next, lets perform a join. We are going to compare the number of registered voters in the voter registration dataset to the same number in the results dataset. Let's join this table we just made from the voter registration dataset to the results dataset, based on precinct number.
#
# How might we do this?

# %%
# Query out the necessary rows
df_resultsRegVoters = df.loc[df['Contest'] == 'REGISTERED VOTERS - TOTAL']

# Create our table with headers and new index for joining
df_summed_resultsRV = df_resultsRegVoters[['PrecNo', 'Count']].astype(int).set_index('PrecNo')
df_summed_resultsRV.columns = ['Count']

# View our table
df_summed_resultsRV.head()

# %%
# run a join!
df_compare = df_summed_extract.join(df_summed_resultsRV, lsuffix='_Extract', rsuffix='_Results')
df_compare

# %%
df_compare['difference'] = np.subtract(df_compare['Count_Extract'], df_compare['Count_Results'])
df_compare

# %% [markdown]
# The numbers are really close, but not quite the same. Why might this be?
